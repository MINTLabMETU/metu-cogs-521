# %% [markdown]
# # Tutorial
#
# ## Part-III
#
# In this live session we will **(a)** reorganize the input as tokenized into analyses, **(b)** parse each analysis into its root and a stream of affixes (another level of tokenization), **(c)** parse the stream into separate morphemes (yet another), **(d)** extract a set of morphemes and **(e)** export the results in *csv* format.

# %% [markdown]
# ### * imports

# %%
import glob
from pprint import pprint

# %% [markdown]
# ### ** globals

# %%
input_path = "./in/"
output_path = "./out/"

# %% [markdown]
# ### *** read input

# %%
def read_and_store_input(input_path):
    # initialize dictionary
    data = {}
    # read file names from the input directory
    input_files = glob.glob(input_path+'*.txt')
    for file_path in input_files:
        content = open(file_path, 'r')
        # create an empty list with a key as the name of the current file
        file_name = file_path.split('/')[-1]
        data[file_name]=[]
        # populate the list with content from file
        for line in content:
            # check if line has content
            if line.strip() != "":
                data[file_name].append(line.strip())
    return data

# %%
data = read_and_store_input(input_path)

# %%
data
# Out:
# {'00001131_pp_ma.txt': ['(nü[JJ])+[Proper=False]/(nü[JJ])+[Proper=True] (Peri[NNP]+[PersonNumber=A3sg]+[Possessive=Pnon]+DA[Case=Loc])+[Proper=True]/(Peride[NNP]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Bare])+[Proper=True]',
#   '(Hakan[NNP]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Bare])+[Proper=True]/(Hakan[NNP]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Nom])+[Proper=True] (Akdoğan[NNP]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Bare])+[Proper=True]/(Akdoğan[NNP]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Nom])+[Proper=True]',
#   '(Roma[NNP]+[PersonNumber=A3sg]+Hn[Possessive=P2sg]+[Case=Bare])+[Proper=True]/(Roma[NNP]+[PersonNumber=A3sg]+Hn[Possessive=P2sg]+[Case=Nom])+[Proper=True]',
#   '(7[CD])+[Proper=False]/(7[CD])+[Proper=True]',
#   '(Koca[NNP]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Bare])+[Proper=True]/(Koca[NNP]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Nom])+[Proper=True] (duvar[NN]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Bare])+[Proper=False]/(duvar[NN]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Bare])+[Proper=True] (taş[VB]+[Polarity=Pos]+Hyor[TenseAspectMood=Prog1]+YDH[Copula=PastCop]+n[PersonNumber=V2sg])+[Proper=False]/(taş[VB]+[Polarity=Pos]+Hyor[TenseAspectMood=Prog1]+YDH[Copula=PastCop]+n[PersonNumber=V2sg])+[Proper=True] (yürek[NN]+[PersonNumber=A3sg]+Hn[Possessive=P2sg]+NDA[Case=Loc])+[Proper=False]/(yürek[NN]+[PersonNumber=A3sg]+Hn[Possessive=P2sg]+NDA[Case=Loc])+[Proper=True] (kimse[NOMP]+[PersonNumber=A3sg]+Hn[Possessive=P2sg]+NHn[Case=Gen]+[Copula=PresCop]+[PersonNumber=V3pl])+[Proper=False]/(kimse[NOMP]+[PersonNumber=A3sg]+Hn[Possessive=P2sg]+NHn[Case=Gen]+[Copula=PresCop]+[PersonNumber=V3pl])+[Proper=True] (aş[VB])([VB]-YA[Derivation=Able]+mA[Polarity=Neg])([NOMP]-YAcAk[Derivation=FutNom]+[PersonNumber=A3sg]+SH[Possessive=P3sg]+[Case=Bare]+[Copula=PresCop]+[PersonNumber=V3pl])+[Proper=False]/(aş[VB])([VB]-YA[Derivation=Able]+mA[Polarity=Neg])([NOMP]-YAcAk[Derivation=FutNom]+[PersonNumber=A3sg]+SH[Possessive=P3sg]+[Case=Bare]+[Copula=PresCop]+[PersonNumber=V3pl])+[Proper=True] (aş[VB]+[Polarity=Pos])([NOMP]-mA[Derivation=Nonf]+[PersonNumber=A3sg]+[Possessive=Pnon]+YA[Case=Dat]+[Copula=PresCop]+[PersonNumber=V3pl])+[Proper=False]/(aş[VB]+[Polarity=Pos])([NOMP]-mA[Derivation=Nonf]+[PersonNumber=A3sg]+[Possessive=Pnon]+YA[Case=Dat]+[Copula=PresCop]+[PersonNumber=V3pl])+[Proper=True] (Cesaret[NNP]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Bare])+[Proper=True]/(Cesaret[NNP]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Nom])+[Proper=True] (et[VB])([VB]-YA[Derivation=Able]+mA[Polarity=Neg])([NOMP]-YAcAk[Derivation=FutNom]+[PersonNumber=A3sg]+SH[Possessive=P3sg]+[Case=Bare]+[Copula=PresCop]+[PersonNumber=V3pl])+[Proper=False]/(et[VB])([VB]-YA[Derivation=Able]+mA[Polarity=Neg])([NOMP]-YAcAk[Derivation=FutNom]+[PersonNumber=A3sg]+SH[Possessive=P3sg]+[Case=Bare]+[Copula=PresCop]+[PersonNumber=V3pl])+[Proper=True] (dış[IN]+[ComplementType=CBare]+[Possessive=Pnon]+YA[Case=Dat])+[Proper=False]/(dış[IN]+[ComplementType=CBare]+[Possessive=Pnon]+YA[Case=Dat])+[Proper=True] (karşı[IN]+[ComplementType=CBare]+[Possessive=Pnon]+[Case=Bare])+[Proper=False]/(karşı[IN]+[ComplementType=CBare]+[Possessive=Pnon]+[Case=Bare])+[Proper=True] (Güç[NNP]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Bare])([NOMP]-lH[Derivation=From]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Bare]+YDH[Copula=PastCop]+[PersonNumber=V3pl])+[Proper=False]/(Güç[NNP]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Bare])([NOMP]-lH[Derivation=From]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Bare]+YDH[Copula=PastCop]+[PersonNumber=V3pl])+[Proper=True] (iç[NN]+[PersonNumber=A3sg]+[Possessive=Pnon]+YA[Case=Dat])+[Proper=False]/(iç[NN]+[PersonNumber=A3sg]+[Possessive=Pnon]+YA[Case=Dat])+[Proper=True] (yürek[NN]+[PersonNumber=A3sg]+Hn[Possessive=P2sg]+NA[Case=Dat])+[Proper=False]/(yürek[NN]+[PersonNumber=A3sg]+Hn[Possessive=P2sg]+NA[Case=Dat])+[Proper=True] (yık[VB])([VB]-Hl[Derivation=Pass]+[Polarity=Pos])([NOMP]-mAk[Derivation=Inf]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Bare]+[Copula=PresCop]+[PersonNumber=V3pl])+[Proper=False]/(yık[VB])([VB]-Hl[Derivation=Pass]+[Polarity=Pos])([NOMP]-mAk[Derivation=Inf]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Bare]+[Copula=PresCop]+[PersonNumber=V3pl])+[Proper=True] (üz[VB]+[Polarity=Pos])([NOMP]-Ar[Derivation=AorNom]+[PersonNumber=A3sg]+[Possessive=Pnon]+YA[Case=Dat]+YDH[Copula=PastCop]+[PersonNumber=V3pl])+[Proper=False]/(üz[VB]+[Polarity=Pos])([NOMP]-Ar[Derivation=AorNom]+[PersonNumber=A3sg]+[Possessive=Pnon]+YA[Case=Dat]+YDH[Copula=PastCop]+[PersonNumber=V3pl])+[Proper=True] (Anı[NNP]+[PersonNumber=A3sg]+[Possessive=Pnon]+[Case=Bare])([NN]-lAr[Derivation=Fam]+[PersonNumber=A3sg]+[Possessive=Pnon]+YlA[Case=Ins])+[Proper=False]/(Anı[NNP]+[ ...

# %% [markdown]
# ## database
#
# **current**:
# ```
#     {
#         file_1:[line_1, ..., line_n],
#         ...,
#         file_m:[line_1, ..., line_k]
#     }
# ```
#
# **envisioned**:
# ```
#     {
#         file_name: {
#                         word_index: {
#                                         analysis_index: {
#                                                             'root'  :root,
#                                                             'aff'   :[affixes],
#                                                             'pos'   :pos_tag,
#                                                             'proper':bool
#                                                         }
#                                     }
#                     }
#     }
# ```

# %% [markdown]
# ### (a-1) tokenize lines into streams of analyses
# note that each stream corresponds to a word in the original data; associated **delimiter** is a `single (white)space`, or, `' '`.

# %%
def tokenizer_l2s(data):
    # 'l' for line, 's' for stream
    # traverse data
    for file, content in data.items():
        stream_index = 0
        streams = {}
        for line in content:
            # split() = split(' ')
            for stream in line.split():
                streams[stream_index] = stream
                stream_index += 1
                # {file_name:{stream_index:stream,...}}
        # make changes in situ, i.e. update
        data[file] = streams

# %%
tokenizer_l2s(data)

# %%
data['00001131_pp_ma.txt'][40]
# Out:
# '(Sefer[NNP]+[PersonNumber=A3sg]+Hn[Possessive=P2sg]+NDA[Case=Loc])+[Proper=True]/(Sefer[NNP]+[PersonNumber=A3sg]+SH[Possessive=P3sg]+NDA[Case=Loc])+[Proper=True]'

# %% [markdown]
# ### (a-2) tokenize streams into individual analyses
# associated **delimiter** is a `forward slash`, or, `'/'`.

# %%
def tokenizer_s2a(data):
    # 's' for stream, 'a' for analysis
    # traverse data
    for file, streams in data.items():
        for stream_index, stream in streams.items():
            analyses = {}
            for index, analysis in enumerate(stream.split('/')):
                analyses[index] = analysis
            # make changes in situ
            data[file][stream_index] = analyses

# %%
tokenizer_s2a(data)

# %%
data['00001131_pp_ma.txt'][40]
# Out:
# {0: '(Sefer[NNP]+[PersonNumber=A3sg]+Hn[Possessive=P2sg]+NDA[Case=Loc])+[Proper=True]',
#  1: '(Sefer[NNP]+[PersonNumber=A3sg]+SH[Possessive=P3sg]+NDA[Case=Loc])+[Proper=True]'}

# %% [markdown]
# ### (b-1) tokenize each analysis into a tuple: (morp, is_proper)
# associated **delimiter** is a `complex custom string`, in this case, `'+[Proper='`. for why, please refer to the manual of the morphological analyzer used in tutorial part II ([here](https://github.com/google-research/turkish-morphology)).

# %%
def tokenizer_a2t(data):
    # 'a' for analysis, 't' for tuple
    for file, streams in data.items():
        for stream_index, stream in streams.items():
            for analysis_index, analysis in stream.items():
                morphology, is_proper = analysis.split('+[Proper=')
                is_proper = is_proper.strip(']')
                if is_proper == 'False':
                    is_proper = False
                elif is_proper == 'True':
                    is_proper = True
                else:
                    raise ValueError('unexpected value')
                tup = (morphology, is_proper)
                # update
                data[file][stream_index][analysis_index] = tup

# %%
tokenizer_a2t(data)

# %%
data['00001131_pp_ma.txt'][40]
# Out:
# {0: ('(Sefer[NNP]+[PersonNumber=A3sg]+Hn[Possessive=P2sg]+NDA[Case=Loc])',
#   True),
#  1: ('(Sefer[NNP]+[PersonNumber=A3sg]+SH[Possessive=P3sg]+NDA[Case=Loc])',
#   True)}

# %% [markdown]
# ### (b-2, c) tokenize morphology into roots, affixes and PoS tags
# associated **delimiters** are `plus`, `minus` and `forward square bracket` characters, or, `'+'`, `'-'` and `'['` respectively.

# %%
def init_values():
    values = {
                'root':None,
                'affixes': None,
                'pos':None,
                'is_proper':None
            }
    return values

def tokenizer_m2c(data):
    # 'm' for morphology, 'c' for category
    for file, streams in data.items():
        for stream_index, stream in streams.items():
            for analysis_index, analysis in stream.items():
                morphology, is_proper = analysis
                # clean morphology
                # this will remove grouping info.
                morphology = ''.join(ch for ch in morphology if ch not in '()')
                # split morphology
                parts = [part for chunk in morphology.split('+') for part in chunk.split('-')]
                root_and_pos = parts[0]
                root = root_and_pos.split('[')[0]
                pos = root_and_pos.split('[')[1].strip(']')
                if len(parts) > 1:
                    affixes = parts[1:]
                else:
                    affixes = None
                # init values
                values = init_values()
                values['root'] = root
                values['affixes'] = affixes
                values['pos'] = pos
                values['is_proper'] = is_proper
                # update
                data[file][stream_index][analysis_index] = values

# %%
tokenizer_m2c(data)

# %%
pprint(data['00001131_pp_ma.txt'][40])
# Out:
# {0: {'affixes': ['[PersonNumber=A3sg]', 'Hn[Possessive=P2sg]', 'NDA[Case=Loc]'],
#      'is_proper': True,
#      'pos': 'NNP',
#      'root': 'Sefer'},
#  1: {'affixes': ['[PersonNumber=A3sg]', 'SH[Possessive=P3sg]', 'NDA[Case=Loc]'],
#      'is_proper': True,
#      'pos': 'NNP',
#      'root': 'Sefer'}}

# %%
pprint(data)
# Out:
# {'00001131_pp_ma.txt': {0: {0: {'affixes': None,
#                                 'is_proper': False,
#                                 'pos': 'JJ',
#                                 'root': 'nü'},
#                             1: {'affixes': None,
#                                 'is_proper': True,
#                                 'pos': 'JJ',
#                                 'root': 'nü'}},
#                         1: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                             '[Possessive=Pnon]',
#                                             'DA[Case=Loc]'],
#                                 'is_proper': True,
#                                 'pos': 'NNP',
#                                 'root': 'Peri'},
#                             1: {'affixes': ['[PersonNumber=A3sg]',
#                                             '[Possessive=Pnon]',
#                                             '[Case=Bare]'],
#                                 'is_proper': True,
#                                 'pos': 'NNP',
#                                 'root': 'Peride'}},
#                         2: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                             '[Possessive=Pnon]',
#                                             '[Case=Bare]'],
#                                 'is_proper': True,
#                                 'pos': 'NNP',
#                                 'root': 'Hakan'},
#                             1: {'affixes': ['[PersonNumber=A3sg]',
#                                             '[Possessive=Pnon]',
#                                             '[Case=Nom]'],
#                                 'is_proper': True,
#                                 'pos': 'NNP',
#                                 'root': 'Hakan'}},
#                         3: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                             '[Possessive=Pnon]',
#                                             '[Case=Bare]'],
#                                 'is_proper': True,
#                                 'pos': 'NNP',
#                                 'root': 'Akdoğan'},
#                             1: {'affixes': ['[PersonNumber=A3sg]',
#                                             '[Possessive=Pnon]',
#                                             '[Case=Nom]'],
#                                 'is_proper': True,
#                                 'pos': 'NNP',
#                                 'root': 'Akdoğan'}},
#                         4: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                             'Hn[Possessive=P2sg]',
#                                             '[Case=Bare]'],
#                                 'is_proper': True,
#                                 'pos': 'NNP',
#                                 'root': 'Roma'},
#                             1: {'affixes': ['[PersonNumber=A3sg]',
#                                             'Hn[Possessive=P2sg]',
#                                             '[Case=Nom]'],
#                                 'is_proper': True,
#                                 'pos': 'NNP',
#                                 'root': 'Roma'}},
#                         5: {0: {'affixes': None,
#                                 'is_proper': False,
#                                 'pos': 'CD',
#                                 'root': '7'},
#                             1: {'affixes': None,
#                                 'is_proper': True,
#                                 'pos': 'CD',
#                                 'root': '7'}},
#                         6: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                             '[Possessive=Pnon]',
#                                             '[Case=Bare]'],
#                                 'is_proper': True,
#                                 'pos': 'NNP',
#                                 'root': 'Koca'},
#                             1: {'affixes': ['[PersonNumber=A3sg]',
#                                             '[Possessive=Pnon]',
#                                             '[Case=Nom]'],
#                                 'is_proper': True,
#                                 'pos': 'NNP',
#                                 'root': 'Koca'}},
#                         7: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                             '[Possessive=Pnon]',
#                                             '[Case=Bare]'],
#                                 'is_proper': False,
#                                 'pos': 'NN',
#                                 'root': 'duvar'},
#                             1: {'affixes': ['[PersonNumber=A3sg]',
#                                             '[Possessive=Pnon]',
#                                             '[Case=Bare]'],
#                                 'is_proper': True,
#                                 'pos': 'NN',
#                                 'root': 'duvar'}},
#                         8: {0: {'affixes': ['[Polarity=Pos]',
#                                             'Hyor[TenseAspectMood=Prog1]',
#                                             'YDH[Copula=PastCop]',
#                                             'n[PersonNumber=V2sg]'],
#                                 'is_proper': False,
#                                 'pos': 'VB',
#                                 'root': 'taş'},
#                             1: {'affixes': ['[Polarity=Pos]',
#                                             'Hyor[TenseAspectMood=Prog1]',
#                                             'YDH[Copula=PastCop]',
#                                             'n[PersonNumber=V2sg]'],
#                                 'is_proper': True,
#                                 'pos': 'VB',
#                                 'root': 'taş'}},
#                         9: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                             'Hn[Possessive=P2sg]',
#                                             'NDA[Case=Loc]'],
#                                 'is_proper': False,
#                                 'pos': 'NN',
#                                 'root': 'yürek'},
#                             1: {'affixes': ['[PersonNumber=A3sg]',
#                                             'Hn[Possessive=P2sg]',
#                                             'NDA[Case=Loc]'],
#                                 'is_proper': True,
#                                 'pos': 'NN',
#                                 'root': 'yürek'}},
#                         10: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              'Hn[Possessive=P2sg]',
#                                              'NHn[Case=Gen]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'NOMP',
#                                  'root': 'kimse'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              'Hn[Possessive=P2sg]',
#                                              'NHn[Case=Gen]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'NOMP',
#                                  'root': 'kimse'}},
#                         11: {0: {'affixes': ['YA[Derivation=Able]',
#                                              'mA[Polarity=Neg][NOMP]',
#                                              'YAcAk[Derivation=FutNom]',
#                                              '[PersonNumber=A3sg]',
#                                              'SH[Possessive=P3sg]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'aş'},
#                              1: {'affixes': ['YA[Derivation=Able]',
#                                              'mA[Polarity=Neg][NOMP]',
#                                              'YAcAk[Derivation=FutNom]',
#                                              '[PersonNumber=A3sg]',
#                                              'SH[Possessive=P3sg]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'aş'}},
#                         12: {0: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'mA[Derivation=Nonf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'aş'},
#                              1: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'mA[Derivation=Nonf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'aş'}},
#                         13: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]'],
#                                  'is_proper': True,
#                                  'pos': 'NNP',
#                                  'root': 'Cesaret'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Nom]'],
#                                  'is_proper': True,
#                                  'pos': 'NNP',
#                                  'root': 'Cesaret'}},
#                         14: {0: {'affixes': ['YA[Derivation=Able]',
#                                              'mA[Polarity=Neg][NOMP]',
#                                              'YAcAk[Derivation=FutNom]',
#                                              '[PersonNumber=A3sg]',
#                                              'SH[Possessive=P3sg]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'et'},
#                              1: {'affixes': ['YA[Derivation=Able]',
#                                              'mA[Polarity=Neg][NOMP]',
#                                              'YAcAk[Derivation=FutNom]',
#                                              '[PersonNumber=A3sg]',
#                                              'SH[Possessive=P3sg]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'et'}},
#                         15: {0: {'affixes': ['[ComplementType=CBare]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]'],
#                                  'is_proper': False,
#                                  'pos': 'IN',
#                                  'root': 'dış'},
#                              1: {'affixes': ['[ComplementType=CBare]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]'],
#                                  'is_proper': True,
#                                  'pos': 'IN',
#                                  'root': 'dış'}},
#                         16: {0: {'affixes': ['[ComplementType=CBare]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]'],
#                                  'is_proper': False,
#                                  'pos': 'IN',
#                                  'root': 'karşı'},
#                              1: {'affixes': ['[ComplementType=CBare]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]'],
#                                  'is_proper': True,
#                                  'pos': 'IN',
#                                  'root': 'karşı'}},
#                         17: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][NOMP]',
#                                              'lH[Derivation=From]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'NNP',
#                                  'root': 'Güç'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][NOMP]',
#                                              'lH[Derivation=From]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'NNP',
#                                  'root': 'Güç'}},
#                         18: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]'],
#                                  'is_proper': False,
#                                  'pos': 'NN',
#                                  'root': 'iç'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]'],
#                                  'is_proper': True,
#                                  'pos': 'NN',
#                                  'root': 'iç'}},
#                         19: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              'Hn[Possessive=P2sg]',
#                                              'NA[Case=Dat]'],
#                                  'is_proper': False,
#                                  'pos': 'NN',
#                                  'root': 'yürek'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              'Hn[Possessive=P2sg]',
#                                              'NA[Case=Dat]'],
#                                  'is_proper': True,
#                                  'pos': 'NN',
#                                  'root': 'yürek'}},
#                         20: {0: {'affixes': ['Hl[Derivation=Pass]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'mAk[Derivation=Inf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'yık'},
#                              1: {'affixes': ['Hl[Derivation=Pass]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'mAk[Derivation=Inf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'yık'}},
#                         21: {0: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'Ar[Derivation=AorNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'üz'},
#                              1: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'Ar[Derivation=AorNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'üz'}},
#                         22: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][NN]',
#                                              'lAr[Derivation=Fam]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YlA[Case=Ins]'],
#                                  'is_proper': False,
#                                  'pos': 'NNP',
#                                  'root': 'Anı'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][NN]',
#                                              'lAr[Derivation=Fam]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YlA[Case=Ins]'],
#                                  'is_proper': True,
#                                  'pos': 'NNP',
#                                  'root': 'Anı'}},
#                         23: {0: {'affixes': ['Hl[Derivation=Pass]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'mHş[Derivation=PerNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'ör'},
#                              1: {'affixes': ['Hl[Derivation=Pass]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'mHş[Derivation=PerNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'ör'}},
#                         24: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][NN]',
#                                              'CH[Derivation=Agt]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][VB]',
#                                              'lA[Derivation=Make]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'Hr[Derivation=AorNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YlA[Case=Ins]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'NN',
#                                  'root': 'a'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][NN]',
#                                              'CH[Derivation=Agt]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][VB]',
#                                              'lA[Derivation=Make]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'Hr[Derivation=AorNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YlA[Case=Ins]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'NN',
#                                  'root': 'a'}},
#                         25: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][VB]',
#                                              'lA[Derivation=Make][VB]',
#                                              'Hn[Derivation=Pass]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'mHş[Derivation=PerNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'NN',
#                                  'root': 'harç'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][VB]',
#                                              'lA[Derivation=Make][VB]',
#                                              'Hn[Derivation=Pass]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'mHş[Derivation=PerNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'NN',
#                                  'root': 'harç'}},
#                         26: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]'],
#                                  'is_proper': False,
#                                  'pos': 'NN',
#                                  'root': 'duvar'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]'],
#                                  'is_proper': True,
#                                  'pos': 'NN',
#                                  'root': 'duvar'}},
#                         27: {0: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'mAk[Derivation=Inf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'tırman'},
#                              1: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'mAk[Derivation=Inf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'tırman'}},
#                         28: {0: {'affixes': ['[Polarity=Pos][VB]',
#                                              'YAbil[Derivation=Able]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'mA[Derivation=Nonf]',
#                                              '[PersonNumber=A3sg]',
#                                              'Hn[Possessive=P2sg]',
#                                              'NHn[Case=Gen]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'aş'},
#                              1: {'affixes': ['[Polarity=Pos][VB]',
#                                              'YAbil[Derivation=Able]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'mA[Derivation=Nonf]',
#                                              '[PersonNumber=A3sg]',
#                                              'Hn[Possessive=P2sg]',
#                                              'NHn[Case=Gen]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'aş'}},
#                         29: {0: {'affixes': None,
#                                  'is_proper': False,
#                                  'pos': 'JJ',
#                                  'root': 'ilk'},
#                              1: {'affixes': None,
#                                  'is_proper': True,
#                                  'pos': 'JJ',
#                                  'root': 'ilk'}},
#                         30: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              'SH[Possessive=P3sg]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'NOMP',
#                                  'root': 'şart'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              'SH[Possessive=P3sg]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'NOMP',
#                                  'root': 'şart'}},
#                         31: {0: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'mAk[Derivation=Inf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'vazgeç'},
#                              1: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'mAk[Derivation=Inf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'vazgeç'}},
#                         32: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'NOMP',
#                                  'root': 'kol'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'NOMP',
#                                  'root': 'kol'}},
#                         33: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][VB]',
#                                              'lA[Derivation=Make]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'mAk[Derivation=Inf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'NNP',
#                                  'root': 'Erte'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][VB]',
#                                              'lA[Derivation=Make]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'mAk[Derivation=Inf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'NNP',
#                                  'root': 'Erte'}},
#                         34: {0: {'affixes': ['[ConjunctionType=Adv]'],
#                                  'is_proper': False,
#                                  'pos': 'CC',
#                                  'root': 'de'},
#                              1: {'affixes': ['[ConjunctionType=Adv]'],
#                                  'is_proper': True,
#                                  'pos': 'CC',
#                                  'root': 'de'}},
#                         35: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              'Hm[Possessive=P1sg]',
#                                              'NA[Case=Dat]'],
#                                  'is_proper': False,
#                                  'pos': 'NN',
#                                  'root': 'a'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              'Hm[Possessive=P1sg]',
#                                              'NA[Case=Dat]'],
#                                  'is_proper': True,
#                                  'pos': 'NN',
#                                  'root': 'a'}},
#                         36: {0: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'mA[Derivation=Nonf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'tırman'},
#                              1: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'mA[Derivation=Nonf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'tırman'}},
#                         37: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][VB]',
#                                              'lA[Derivation=Make][VB]',
#                                              'Hn[Derivation=Pass]',
#                                              '[Polarity=Pos]',
#                                              'DH[TenseAspectMood=Past]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'NN',
#                                  'root': 'baş'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][VB]',
#                                              'lA[Derivation=Make][VB]',
#                                              'Hn[Derivation=Pass]',
#                                              '[Polarity=Pos]',
#                                              'DH[TenseAspectMood=Past]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'NN',
#                                  'root': 'baş'}},
#                         38: {0: {'affixes': ['Hr[Derivation=Cau][VB]',
#                                              'Hl[Derivation=Pass]',
#                                              '[Polarity=Pos][VN]',
#                                              'mA[Derivation=Nonf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][JJ]',
#                                              'lH[Derivation=With]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'bit'},
#                              1: {'affixes': ['Hr[Derivation=Cau][VB]',
#                                              'Hl[Derivation=Pass]',
#                                              '[Polarity=Pos][VN]',
#                                              'mA[Derivation=Nonf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][JJ]',
#                                              'lH[Derivation=With]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'bit'}},
#                         39: {0: {'affixes': ['[ConjunctionType=Coor]'],
#                                  'is_proper': False,
#                                  'pos': 'CC',
#                                  'root': 'çünkü'},
#                              1: {'affixes': ['[ConjunctionType=Coor]'],
#                                  'is_proper': True,
#                                  'pos': 'CC',
#                                  'root': 'çünkü'}},
#                         40: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              'Hn[Possessive=P2sg]',
#                                              'NDA[Case=Loc]'],
#                                  'is_proper': True,
#                                  'pos': 'NNP',
#                                  'root': 'Sefer'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              'SH[Possessive=P3sg]',
#                                              'NDA[Case=Loc]'],
#                                  'is_proper': True,
#                                  'pos': 'NNP',
#                                  'root': 'Sefer'}},
#                         41: {0: {'affixes': ['[Polarity=Pos][VN]',
#                                              'mA[Derivation=Nonf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][JJ]',
#                                              'sHz[Derivation=Wout]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'acı'},
#                              1: {'affixes': ['[Polarity=Pos][VN]',
#                                              'mA[Derivation=Nonf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][JJ]',
#                                              'sHz[Derivation=Wout]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'acı'}},
#                         42: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]'],
#                                  'is_proper': False,
#                                  'pos': 'NN',
#                                  'root': 'geri'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]'],
#                                  'is_proper': True,
#                                  'pos': 'NN',
#                                  'root': 'geri'}},
#                         43: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]'],
#                                  'is_proper': True,
#                                  'pos': 'NNP',
#                                  'root': 'Dönüş'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Nom]'],
#                                  'is_proper': True,
#                                  'pos': 'NNP',
#                                  'root': 'Dönüş'}},
#                         44: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'NOMP',
#                                  'root': 'var'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'NOMP',
#                                  'root': 'var'}},
#                         45: {0: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'DHk[Derivation=PastNom]',
#                                              '[PersonNumber=A3sg]',
#                                              'Hn[Possessive=P2sg]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'bırak'},
#                              1: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'DHk[Derivation=PastNom]',
#                                              '[PersonNumber=A3sg]',
#                                              'Hn[Possessive=P2sg]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'bırak'}},
#                         46: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]'],
#                                  'is_proper': True,
#                                  'pos': 'NNP',
#                                  'root': 'Sefer'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Nom]'],
#                                  'is_proper': True,
#                                  'pos': 'NNP',
#                                  'root': 'Sefer'}},
#                         47: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]'],
#                                  'is_proper': False,
#                                  'pos': 'NN',
#                                  'root': 'başlangıç'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]'],
#                                  'is_proper': True,
#                                  'pos': 'NN',
#                                  'root': 'başlangıç'}},
#                         48: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'NOMP',
#                                  'root': 'gebe'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'NOMP',
#                                  'root': 'gebe'}},
#                         49: {0: {'affixes': ['[ConjunctionType=Adv]'],
#                                  'is_proper': False,
# ...
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'NN',
#                                  'root': 'korku'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][VB]',
#                                              'lA[Derivation=Make]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'Hr[Derivation=AorNom]',
#                                              '[PersonNumber=A3sg]',
#                                              'Hn[Possessive=P2sg]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'NN',
#                                  'root': 'korku'}},
#                         57: {0: {'affixes': ['[Polarity=Pos][CRB]',
#                                              'YHp[Derivation=After]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'eri'},
#                              1: {'affixes': ['[Polarity=Pos][CRB]',
#                                              'YHp[Derivation=After]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'eri'}},
#                         58: {0: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'YAcAk[Derivation=FutNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'git'},
#                              1: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'YAcAk[Derivation=FutNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'git'}},
#                         59: {0: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'YAcAk[Derivation=FutNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'ol'},
#                              1: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'YAcAk[Derivation=FutNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'ol'}},
#                         60: {0: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'YAcAk[Derivation=FutNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'geç'},
#                              1: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'YAcAk[Derivation=FutNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'geç'}},
#                         61: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]'],
#                                  'is_proper': False,
#                                  'pos': 'NN',
#                                  'root': 'ben'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]'],
#                                  'is_proper': True,
#                                  'pos': 'NN',
#                                  'root': 'ben'}},
#                         62: {0: {'affixes': ['Hn[Derivation=Pass]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'YAcAk[Derivation=FutNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              'm[PersonNumber=V1sg]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'kıvra'},
#                              1: {'affixes': ['Hn[Derivation=Pass]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'YAcAk[Derivation=FutNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              'm[PersonNumber=V1sg]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'kıvra'}},
#                         63: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][JJ]',
#                                              'CH[Derivation=Agt]'],
#                                  'is_proper': False,
#                                  'pos': 'NN',
#                                  'root': 'a'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][JJ]',
#                                              'CH[Derivation=Agt]'],
#                                  'is_proper': True,
#                                  'pos': 'NN',
#                                  'root': 'a'}},
#                         64: {0: {'affixes': ['[Polarity=Pos][CRB]',
#                                              'YHp[Derivation=After]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'çek'},
#                              1: {'affixes': ['[Polarity=Pos][CRB]',
#                                              'YHp[Derivation=After]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'çek'}},
#                         65: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][VB]',
#                                              'lA[Derivation=Make]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'Hr[Derivation=AorNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'NN',
#                                  'root': 'işkence'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][VB]',
#                                              'lA[Derivation=Make]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'Hr[Derivation=AorNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'YA[Case=Dat]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'NN',
#                                  'root': 'işkence'}},
#                         66: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][JJ]',
#                                              'lH[Derivation=From]'],
#                                  'is_proper': False,
#                                  'pos': 'NNP',
#                                  'root': 'Gönül'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][JJ]',
#                                              'lH[Derivation=From]'],
#                                  'is_proper': True,
#                                  'pos': 'NNP',
#                                  'root': 'Gönül'}},
#                         67: {0: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][VB]',
#                                              'lA[Derivation=Make][VB]',
#                                              'Hn[Derivation=Pass]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'YAcAk[Derivation=FutNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              'm[PersonNumber=V1sg]'],
#                                  'is_proper': False,
#                                  'pos': 'NN',
#                                  'root': 'kat'},
#                              1: {'affixes': ['[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare][VB]',
#                                              'lA[Derivation=Make][VB]',
#                                              'Hn[Derivation=Pass]',
#                                              '[Polarity=Pos][NOMP]',
#                                              'YAcAk[Derivation=FutNom]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              '[Case=Bare]',
#                                              'YDH[Copula=PastCop]',
#                                              'm[PersonNumber=V1sg]'],
#                                  'is_proper': True,
#                                  'pos': 'NN',
#                                  'root': 'kat'}},
#                         68: {0: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'r[Derivation=AorNom]',
#                                              '[PersonNumber=A3sg]',
#                                              'Hn[Possessive=P2sg]',
#                                              'NA[Case=Dat]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'ye'},
#                              1: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'r[Derivation=AorNom]',
#                                              '[PersonNumber=A3sg]',
#                                              'Hn[Possessive=P2sg]',
#                                              'NA[Case=Dat]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'ye'}},
#                         69: {0: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'mA[Derivation=Nonf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'DAn[Case=Abl]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': False,
#                                  'pos': 'VB',
#                                  'root': 'bil'},
#                              1: {'affixes': ['[Polarity=Pos][NOMP]',
#                                              'mA[Derivation=Nonf]',
#                                              '[PersonNumber=A3sg]',
#                                              '[Possessive=Pnon]',
#                                              'DAn[Case=Abl]',
#                                              '[Copula=PresCop]',
#                                              '[PersonNumber=V3pl]'],
#                                  'is_proper': True,
#                                  'pos': 'VB',
#                                  'root': 'bil'}}}}

# %% [markdown]
# ### (d) extract a set of roots and affixes

# %% [markdown]
# ### (e-1) export the data in *csv* format
# let the fields be `'file_name'`, `'word_index'`, `'analysis_index'`, `'root'`, `'pos'`, `'is_prop'` and `morpheme_types`

# %%
def catalog(data):
    cat = {'roots':[], 'affixes':[]}
    for file, words in data.items():
        for w_index, word in words.items():
            for a_index, analysis in word.items():
                root = analysis['root']
                if root not in cat['roots']:
                    cat['roots'].append(root)
                affixes = analysis['affixes']
                # check if morph. analysis yielded any affixes
                if affixes:
                    for affix in affixes:
                        if affix not in cat['affixes']:
                            cat['affixes'].append(affix)
    return cat

# %%
cat = catalog(data)

# %%
pprint(cat)
# Out:
# {'affixes': ['[PersonNumber=A3sg]',
#              '[Possessive=Pnon]',
#              'DA[Case=Loc]',
#              '[Case=Bare]',
#              '[Case=Nom]',
#              'Hn[Possessive=P2sg]',
#              '[Polarity=Pos]',
#              'Hyor[TenseAspectMood=Prog1]',
#              'YDH[Copula=PastCop]',
#              'n[PersonNumber=V2sg]',
#              'NDA[Case=Loc]',
#              'NHn[Case=Gen]',
#              '[Copula=PresCop]',
#              '[PersonNumber=V3pl]',
#              'YA[Derivation=Able]',
#              'mA[Polarity=Neg][NOMP]',
#              'YAcAk[Derivation=FutNom]',
#              'SH[Possessive=P3sg]',
#              '[Polarity=Pos][NOMP]',
#              'mA[Derivation=Nonf]',
#              'YA[Case=Dat]',
#              '[ComplementType=CBare]',
#              '[Case=Bare][NOMP]',
#              'lH[Derivation=From]',
#              'NA[Case=Dat]',
#              'Hl[Derivation=Pass]',
#              'mAk[Derivation=Inf]',
#              'Ar[Derivation=AorNom]',
#              '[Case=Bare][NN]',
#              'lAr[Derivation=Fam]',
#              'YlA[Case=Ins]',
#              'mHş[Derivation=PerNom]',
#              'CH[Derivation=Agt]',
#              '[Case=Bare][VB]',
#              'lA[Derivation=Make]',
#              'Hr[Derivation=AorNom]',
#              'lA[Derivation=Make][VB]',
#              'Hn[Derivation=Pass]',
#              '[Polarity=Pos][VB]',
#              'YAbil[Derivation=Able]',
#              '[ConjunctionType=Adv]',
#              'Hm[Possessive=P1sg]',
#              'DH[TenseAspectMood=Past]',
#              'Hr[Derivation=Cau][VB]',
#              '[Polarity=Pos][VN]',
#              '[Case=Bare][JJ]',
#              'lH[Derivation=With]',
#              '[ConjunctionType=Coor]',
#              'sHz[Derivation=Wout]',
#              'DHk[Derivation=PastNom]',
#              'YsA[Copula=CndCop]',
#              'm[PersonNumber=V1sg]',
#              'YAcAk[TenseAspectMood=Fut]',
#              'lHk[Derivation=For]',
#              '[Polarity=Pos][CRB]',
#              'YHp[Derivation=After]',
#              'r[Derivation=AorNom]',
#              'DAn[Case=Abl]'],
#  'roots': ['nü',
#            'Peri',
#            'Peride',
#            'Hakan',
#            'Akdoğan',
#            'Roma',
#            '7',
#            'Koca',
#            'duvar',
#            'taş',
#            'yürek',
#            'kimse',
#            'aş',
#            'Cesaret',
#            'et',
#            'dış',
#            'karşı',
#            'Güç',
#            'iç',
#            'yık',
#            'üz',
#            'Anı',
#            'ör',
#            'a',
#            'harç',
#            'tırman',
#            'ilk',
#            'şart',
#            'vazgeç',
#            'kol',
#            'Erte',
#            'de',
#            'baş',
#            'bit',
#            'çünkü',
#            'Sefer',
#            'acı',
#            'geri',
#            'Dönüş',
#            'var',
#            'bırak',
#            'başlangıç',
#            'gebe',
#            'bir',
#            'ol',
#            'kucak',
#            'ben',
#            'kırgın',
#            'korku',
#            'eri',
#            'git',
#            'geç',
#            'kıvra',
#            'çek',
#            'işkence',
#            'Gönül',
#            'kat',
#            'ye',
#            'bil']}

# %%
fields = ['file_index', 'word_index', 'analysis_index', 'root', 'pos', 'is_proper'] + ['afx:'+affix for affix in cat['affixes']]

# %%
print(len(fields))
pprint(fields)
# Out:
# 64
# ['file_index',
#  'word_index',
#  'analysis_index',
#  'root',
#  'pos',
#  'is_proper',
#  'afx:[PersonNumber=A3sg]',
#  'afx:[Possessive=Pnon]',
#  'afx:DA[Case=Loc]',
#  'afx:[Case=Bare]',
#  'afx:[Case=Nom]',
#  'afx:Hn[Possessive=P2sg]',
#  'afx:[Polarity=Pos]',
#  'afx:Hyor[TenseAspectMood=Prog1]',
#  'afx:YDH[Copula=PastCop]',
#  'afx:n[PersonNumber=V2sg]',
#  'afx:NDA[Case=Loc]',
#  'afx:NHn[Case=Gen]',
#  'afx:[Copula=PresCop]',
#  'afx:[PersonNumber=V3pl]',
#  'afx:YA[Derivation=Able]',
#  'afx:mA[Polarity=Neg][NOMP]',
#  'afx:YAcAk[Derivation=FutNom]',
#  'afx:SH[Possessive=P3sg]',
#  'afx:[Polarity=Pos][NOMP]',
#  'afx:mA[Derivation=Nonf]',
#  'afx:YA[Case=Dat]',
#  'afx:[ComplementType=CBare]',
#  'afx:[Case=Bare][NOMP]',
#  'afx:lH[Derivation=From]',
#  'afx:NA[Case=Dat]',
#  'afx:Hl[Derivation=Pass]',
#  'afx:mAk[Derivation=Inf]',
#  'afx:Ar[Derivation=AorNom]',
#  'afx:[Case=Bare][NN]',
#  'afx:lAr[Derivation=Fam]',
#  'afx:YlA[Case=Ins]',
#  'afx:mHş[Derivation=PerNom]',
#  'afx:CH[Derivation=Agt]',
#  'afx:[Case=Bare][VB]',
#  'afx:lA[Derivation=Make]',
#  'afx:Hr[Derivation=AorNom]',
#  'afx:lA[Derivation=Make][VB]',
#  'afx:Hn[Derivation=Pass]',
#  'afx:[Polarity=Pos][VB]',
#  'afx:YAbil[Derivation=Able]',
#  'afx:[ConjunctionType=Adv]',
#  'afx:Hm[Possessive=P1sg]',
#  'afx:DH[TenseAspectMood=Past]',
#  'afx:Hr[Derivation=Cau][VB]',
#  'afx:[Polarity=Pos][VN]',
#  'afx:[Case=Bare][JJ]',
#  'afx:lH[Derivation=With]',
#  'afx:[ConjunctionType=Coor]',
#  'afx:sHz[Derivation=Wout]',
#  'afx:DHk[Derivation=PastNom]',
#  'afx:YsA[Copula=CndCop]',
#  'afx:m[PersonNumber=V1sg]',
#  'afx:YAcAk[TenseAspectMood=Fut]',
#  'afx:lHk[Derivation=For]',
#  'afx:[Polarity=Pos][CRB]',
#  'afx:YHp[Derivation=After]',
#  'afx:r[Derivation=AorNom]',
#  'afx:DAn[Case=Abl]']

# %%
def to_csv(data, fields, affix_cat, output_path):
    csv = open(output_path+'data.csv', 'w')
    for file_name, content in data.items():
        f_index = file_name.split('_')[0]
        # init file
        fields_line = ','.join(field for field in fields)
        csv.write(fields_line+'\n')
        for w_index, word in content.items():
            for a_index, analysis in word.items():
                root = analysis['root']
                pos = analysis['pos']
                is_proper = str((int(analysis['is_proper'])))
                affixes = analysis['affixes']
                if not affixes:
                    affixes = []
                csv.write(f_index+',')
                csv.write(str(w_index)+',')
                csv.write(str(a_index)+',')
                csv.write(root+',')
                csv.write(pos+',')
                csv.write(is_proper+',')
                for cat in affix_cat:
                    if cat in affixes:
                        csv.write('1,')
                    else:
                        csv.write('0,')
                csv.write('\n')
    csv.close()

# %%
to_csv(data, fields, cat['affixes'], output_path)

# %% [markdown]
# ### (e-2) export the catalog into two files
